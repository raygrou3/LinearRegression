# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set()
# %matplotlib inline

# %%
xx = np.array([-0.51, 51.2])
yy = np.array([0.33, 51.6])
means = [xx.mean(), yy.mean()]  
stds = [xx.std() / 3, yy.std() / 3]
corr = 0.8         # correlation
covs = [[stds[0]**2          , stds[0]*stds[1]*corr], 
        [stds[0]*stds[1]*corr,           stds[1]**2]] 

m = np.random.multivariate_normal(means, covs, 1000).T

# %%
df=pd.DataFrame()

# %%
df['exp(in months)']=m[0]
df['salary(in thousands)']=m[1]

# %%
df
# Out:
#      exp(in months)  salary(in thousands)
# 0         34.001469             35.394018
# 1         25.697794             21.663215
# 2         12.421999             20.064812
# 3         33.577826             36.980108
# 4         28.124353             22.470344
# ..              ...                   ...
# 995       20.494918             19.218245
# 996       21.160581             21.069737
# 997       34.590048             33.327395
# 998       27.306002             31.737788
# 999       29.497509             28.025709
#
# [1000 rows x 2 columns]

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['exp(in months)', 'salary(in thousands)'], dtype='object')

# %%
#X=df[['exp(in months)']]

# %%
X=df.iloc[:,0:1].values

# %%
X
# Out:
# array([[34.00146948],
#        [25.69779403],
#        [12.42199861],
#        [33.5778263 ],
#        [28.12435307],
#        [28.66864377],
#        [32.21082477],
#        [32.13808164],
#        [21.26825958],
#        [37.06195696],
#        [28.26920269],
#        [23.96001611],
#        [ 6.16634735],
#        [24.88955513],
#        [27.33320432],
#        [26.65319555],
#        [21.57266239],
#        [20.02717623],
#        [26.36638176],
#        [29.50014401],
#        [17.50735487],
#        [23.19051764],
#        [25.27520786],
#        [25.91367734],
#        [30.19271029],
#        [21.84254054],
#        [23.15605201],
#        [26.44812471],
#        [10.21556401],
#        [18.44244073],
#        [22.86927441],
#        [32.65250774],
#        [19.46855047],
#        [21.84662299],
#        [33.39714366],
#        [ 7.58033322],
#        [26.29843992],
#        [23.53427336],
#        [22.8387483 ],
#        [22.03053628],
#        [20.8289318 ],
# ...

# %%
y=df['salary(in thousands)']

# %%
y
# Out:
# 0      35.394018
# 1      21.663215
# 2      20.064812
# 3      36.980108
# 4      22.470344
#          ...
# 995    19.218245
# 996    21.069737
# 997    33.327395
# 998    31.737788
# 999    28.025709
# Name: salary(in thousands), Length: 1000, dtype: float64

# %%
print(X.shape)
# Out:
# (1000, 1)

# %%
print(y.shape)
# Out:
# (1000,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predicted=lm.predict(X_test)

# %% [markdown]
# regresson line is given by y=mx+b
#
# here the slope of line is lm.coef_[0] and the intercept can be
# found using lm.intercept_

# %%
lm.coef_
# Out:
# array([0.79198264])

# %%
lm.coef_[0]
# Out:
# 0.7919826408376934

# %%
lm.intercept_
# Out:
# 5.768798069093705

# %% [markdown]
# y=.79x+5.76

# %%
cdf=pd.DataFrame()

# %%
cdf['y_test']=y_test

# %%
cdf['y_pred']=y_predicted

# %%
df.shape
# Out:
# (1000, 2)

# %%
cdf.shape
# Out:
# (200, 2)

# %%
cdf
# Out:
#         y_test     y_pred
# 471  22.424166  25.443326
# 616   7.558335   7.056248
# 136  36.527860  31.389684
# 708  19.430837  18.891628
# 772  22.112786  20.627032
# ..         ...        ...
# 558  18.857818  22.980180
# 687  24.181144  28.571317
# 296  38.075914  30.746576
# 129  32.699328  35.626431
# 126  21.861018  31.985616
#
# [200 rows x 2 columns]

# %%
plt.scatter(y_test,y_predicted)
plt.plot(X_train,lm.predict(X_train),color='r')

# %%
plt.scatter(y_test,y_predicted)
plt.scatter(X_train,lm.predict(X_train),color='r')

# %%
from sklearn import metrics

# %%
mas=metrics.mean_absolute_error(y_test,y_predicted)
mas
# Out:
# 3.867465546204353

# %%
plt.plot()
